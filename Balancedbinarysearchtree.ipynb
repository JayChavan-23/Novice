# %% [markdown]
# Revision
#
# Binary search trees
#
# Orddered to sorted binary tresss
#
# Nodes can have 2 subtress
#
# Items to the left are smaller then the parent Nodes
#
# Items to the right are bigger than the parent node

# %% [markdown]
# ## Balanced binary search tree
#
# A Balanched Binary search tree has a fixed height of logn

# %% [markdown]
# ## AVL
# An AVL is a self balancing binary search tree
#
# Why is it important to have a balanced binary tree?
# so that lookups can be done in O(logn) i na binary search tree
#
# Balance Factore should be (-1, 0 , +1)
#
# Balance Factor  = Height of left tree - Height of right tree
#
#
# Search -> Insertion and Deletion are Logn

# %% [markdown]
# TO maintain the balance of a AVL when a insertion or a deletion happends we do rotations
#
# there are 4 types of rotations to resotorebalance
#
# - Right rotation
# - left rotation
# - left right rotation
# - right left rotation

# %% [markdown]
# ## Red black tree
#
# Specific type of balanced Binary search tree
#
# Node is either red or black
#
# The Root node and leaf node are always black or nil
#
# If a node is red then it's chilfrens are black
#
# for each node every path to a nil nde has the  same number of black nodes
#
# Search -> Insertion and Deletion are Logn
