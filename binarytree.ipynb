# %% [markdown]
# ## Binary tree
# In a binary tree each node will have atmost 2 values T
#
# Trees are like a subset of Graphs they are directed graphs but they can be made undirected with node.parent
#
# There are always three properties
# - root.val = (Value of the node)
# - root.left - (Pointting to the node on the left of the root node) could be None
# - root,right - Pointing to the node on the right of the root node, could be None
#
# Leaf Node: the node which dont have any childs

# %% [markdown]
# ## Trees
#
# Trees are connected acyclic Graphs
#
# Connected -> From any point in the graph I can go to any other point in the graph
#
# Acyclic -> (does not contain a cycle)
#
# A property about trees if you have v vertices then number of edges will be v-1

# %% [markdown]
# Complete tree - when the tree is almost filled out
#
# Perfect tree - when the tress is perfectly filled out

# %% [markdown]
# Binary tress have heights also called as max depth

# %% [markdown]
# ## To traverse a binary tree we use strategies like DFS | BFS
#
# ### Three types of depth first search
#
# PreOrder - Node , left , right
#
# Inorder - left , Node , Right (We hit the bottom left first)
#
# Postorder - left right node
#
# ### Breadth First Search Level Order

# %% [markdown]
# ## Time Complexity
#
# Lookup for a element ->  O(n)  We have tp go throught the whole tree
#
# Space ->
# Generally it's O(H) - > H is the height of the tree
#
#
# Worst case-> O(n)  If we have something like a likedlist and all the nodes were in the same direction

# %% [markdown]
# ## Binary Search Tree | Ordered Binary Tree

# %% [markdown]
# Binary search tree is basically a complete or a perfect binary tree which has a property that all the nodes on the left side of a parent node whill be smaller than the parent node and ll the ndeps on the right of the bianry tree will be greater than the parent
#
#
# Lookup -> log n
#
# It's good to have it balanced or else it will look like a linkedlist and it will take worst case lookup O(n)
#
# If the Binary search tree is Height balanced then the lookup would be O(logn) but if it is not then worst case would be O(n)

# %% [markdown]
# A cool property about binary search tree, if you traverse the elements via in a in-order traversal method they will be in a sorted order.

# %% [markdown]
# ## AVL
# An AVL is a self balancing binary search tree
#
# Why is it important to have a balanced binary tree?
# so that lookups can be done in O(logn) i na binary search tree
#
# Balance Factore should be (-1, 0 , +1)
#
# Balance Factor  = Height of left tree - Height of right tree

# %% [markdown]
# ## Heap
#
# Heap is basically a complete binary tree
#
# It doesnt have to be a bonary search tree
#
# A tree that satisfies the heap property
#
# 1. Min Heap - Every parent node is <= it's childrens (The lowest element is at the top)
#
# 2. Max Heap - Every parent node is >= it;s childrens (The largest element is at the top)

# %% [markdown]
# ## Priority Queue is basically something that has a prority
#
# could be priority of min elements max elements
#
# hence it is mostly impkemented a a min heap or a max heap becase the
#
# Operatins are fast like
#
# time complexity
# - Insert (logn)
# - Remmove (Logn)
# - lookup (n)
# - Min element (O(1))
