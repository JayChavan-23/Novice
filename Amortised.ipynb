# %% [markdown]
# Amortised TIme is the average time per operations in a sequence of operations
#
# If a single operation in a list of operations is expensive then when spread across many operation the average cost becomes less.
#
# It is used when let;s say
#
# most of the operations are O(1) and after few intervals theres a O(n)

# %% [markdown]
# For example you register to drive on the road for free for 100 days but the registration cost is 100 dollars
# that means there is a expensive cost in the begininng once but aftet that u drive for free but if you distrubute it over 100 days we are actually paying 1 dollar a day

# %% [markdown]
# Most famous example is dynamic array resizing
#
# We use a list and it doubles in size when the list gets full
#
# Lets say on a normal day insertion is O(1) but when the list gets full it need to double the size of the list hence the cost would be O(n)
#
# So let's brake it down
# Most insertions cost O(1) times
# but Ocasiannaly resizing costs O(n)
#
#
# Total cost / N operations
# = O(N) / N
# = O(1)
#
#
# Even tho one insert mayc caused but amortsed time is O(1) because rezing happens rarely

# %% [markdown]
# so technically worst cast time complexity is still O(n) but amaortised time which isaverage is O(1)
