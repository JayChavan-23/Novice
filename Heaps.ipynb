# %% [markdown]
# How to represent a array into a binary tree
#
# - Fill it by level
#
# there are some formulas
#
# If the node is at i
# - the left child will be 2*i
# - right child will be 2*i+1
# - it's parent will be floor value of [i/2]

# %% [markdown]
# ## perfect binary tree
#
# When all the noes and leaf nodes are filled and there is no space for new node the adding in new node will result in new height

# %% [markdown]
# Complete Binary tree
#
# If you are represingthing a binary tree in terms of an array then there should be no empty gaps
#
# Height is logn because we are not going to the next level unless the height is full

# %% [markdown]
# Heap
#
# Hep is way of representation of a complete binary tree
#
# which can be represented as a min heap or a max heap
#
# Mn heap the parent node i akways smaller than the child node
#
# max head the parent ndoe is always larger than th child node

# %% [markdown]
# insertion - logn
#
# search - logn
#
# deletion - logn
#
# Heapsort -> nlogn
